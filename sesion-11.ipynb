# %%
# Para mostrar images
import matplotlib.pyplot as plt
from IPython.core.display import Image

# %matplotlib inline

# %%
from scipy.stats import norm
data = norm.rvs(size=1000000)

# %%
mean, var, skew, kurt = norm.stats(moments='mvsk')
mean, var, skew, kurt
# Out:
# (array(0.), array(1.), array(0.), array(0.))

# %%
ax = sns.distplot(data,
                  bins=500,
                  kde=False,
                  color='blue')
ax.set(xlabel='Distribucion Normal', ylabel='Frequency')
ax.axvline(x = mean, linestyle = '--', label = 'mean')
ax.legend()

# %%
from scipy.stats import expon
data = expon.rvs(size=1000000)

# %%
mean, var, skew, kurt = expon.stats(moments='mvsk')
mean, var, skew, kurt
# Out:
# (array(1.), array(1.), array(2.), array(6.))

# %%
ax = sns.distplot(data,
                  bins=500,
                  kde=False,
                  color='blue')
ax.set(xlabel='Distribucion Exponencial', ylabel='Frequency')
ax.axvline(x = mean, linestyle = '--', label = 'mean')
ax.legend()

# %%
from scipy.stats import uniform
data = uniform.rvs(size=1000000)

# %%
mean, var, skew, kurt = uniform.stats(moments='mvsk')
mean, var, skew, kurt
# Out:
# (array(0.5), array(0.08333333), array(0.), array(-1.2))

# %%
ax = sns.distplot(data,
                  bins=500,
                  kde=False,
                  color='blue')
ax.set(xlabel='Distribución Uniforme 0 - 1', ylabel='Frequency')
ax.axvline(x = mean, linestyle = '--', label = 'mean')
ax.legend()
